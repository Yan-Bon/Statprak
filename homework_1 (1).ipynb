# %% [markdown]
# Make a tuple containing natural numbers, the square of which is a multiple of 3, 4, but not a multiple of 8 and not exceeding 12345.

# %%
t = tuple([x for x in range(12345) if pow(x, 2) % 12 == 0 and pow(x, 2) % 8 != 0])
print(t)
# Out:
# (6, 18, 30, 42, 54, 66, 78, 90, 102, 114, 126, 138, 150, 162, 174, 186, 198, 210, 222, 234, 246, 258, 270, 282, 294, 306, 318, 330, 342, 354, 366, 378, 390, 402, 414, 426, 438, 450, 462, 474, 486, 498, 510, 522, 534, 546, 558, 570, 582, 594, 606, 618, 630, 642, 654, 666, 678, 690, 702, 714, 726, 738, 750, 762, 774, 786, 798, 810, 822, 834, 846, 858, 870, 882, 894, 906, 918, 930, 942, 954, 966, 978, 990, 1002, 1014, 1026, 1038, 1050, 1062, 1074, 1086, 1098, 1110, 1122, 1134, 1146, 1158, 1170, 1182, 1194, 1206, 1218, 1230, 1242, 1254, 1266, 1278, 1290, 1302, 1314, 1326, 1338, 1350, 1362, 1374, 1386, 1398, 1410, 1422, 1434, 1446, 1458, 1470, 1482, 1494, 1506, 1518, 1530, 1542, 1554, 1566, 1578, 1590, 1602, 1614, 1626, 1638, 1650, 1662, 1674, 1686, 1698, 1710, 1722, 1734, 1746, 1758, 1770, 1782, 1794, 1806, 1818, 1830, 1842, 1854, 1866, 1878, 1890, 1902, 1914, 1926, 1938, 1950, 1962, 1974, 1986, 1998, 2010, 2022, 2034, 2046, 2058, 2070, 2082, 2094, 2106, 2118, 2130, 2142, 2154, 2166, 217
# ...

# %% [markdown]
# Write a function that takes a two-dimensional array and a string as input and returns an array rotated 90 degrees counterclockwise if the string 'left' was passed, and clockwise if the string 'right' was passed.

# %%
def rotate_left(matrix):
  return [list(row)[::-1] for row in zip(*matrix)]

def rotate(matrix, direction):
  if direction == 'left':
    return rotate_left(matrix)
  elif direction == 'right':
    return rotate_left(rotate_left(rotate_left(matrix)))
  return matrix

# %% [markdown]
# Write a function that takes a string as input and returns a dictionary containing the number of occurrences of each character in the string. Use method count of strings. Implement this function in one line using  λ -function.
#
# Example for the string 'hello, world!': {'h': 1, 'e': 1, 'l': 3, 'o': 2, ',': 1, ' ': 1, 'w': 1, 'r': 1, 'd': 1, '!': 1}.

# %%
def count_letters(phrase):
    res = {a: phrase.count(a) for a in phrase}
    return res

cuonted_letters = lambda x: {a: x.count(a) for a in x}

# %% [markdown]
# Implementing a Library Management System
# Description
# You are required to design and implement a system for managing books and users in a library. The system should allow for the management of books (adding, deleting, searching by various criteria) and users (registration, deletion, searching), as well as tracking the history of interactions between them (issuing and returning books).
#
# Tasks
# Book Class:
#
# Attributes: title, author, year of publication, ISBN, number of copies.
# Methods: constructor, methods to get information about the book, method to change the number of copies (when issuing and returning books).
# User Class:
#
# Attributes: user name, library card number, list of borrowed books.
# Methods: constructor, methods for user registration, methods for adding and removing books from the borrowed list.
# Library Class:
#
# Attributes: list of books, list of users, transaction history (who, when, which book was borrowed and returned).
# Methods: constructor, methods for adding and deleting books and users, methods for issuing and returning books, searching for books and users by various criteria, method to display the transaction history.

# %%
from datetime import datetime

class Book:
    def __init__(self, title, author, pub_year, ISBN, copies_num):
        self.title = title
        self.author = author
        self.pub_year = pub_year
        self.ISBN = ISBN
        self.copies_num = copies_num

    def get_book_info(self):
        return(self.title, self.author, self.pub_year, self.ISBN, self.copies_num)

    def change(self, numb):
        self.copies_num += numb


class User:
    def __init__(self, name, card_num):
        self.name = name
        self.card_num = card_num
        self.bor_book_list = []

    def add_book(self, book):
        self.bor_book_list.append(book)

    def delete_book(self, book):
        self.bor_book_list.remove(book)


class Library:
    def __init__(self):
        self.book_list = []
        self.user_list = []
        self.history = []

    def add_book(self, book):
        self.book_list.append(book)

    def delete_book(self, book):
        self.book_list.remove(book)

    def add_user(self, user):
        self.user_list.append(user)

    def delete_user(self, user):
        self.user_list.remove(user)

    def issue_book(self, user, book):
        user.add_book(book)
        book.change(-1)

        self.history.append({'user': user.name, 'book': book.title, 'action': 'issued', 'date': datetime.now()})


    def return_book(self, user, book):
        user.delete_book(book)
        book.change(1)

        self.history.append({'user': user.name, 'book': book.title, 'action': 'returned', 'date': datetime.now()})


    def find_book(self, title):
        books = [book for book in self.book_list if title in book.title]
        return books


    def find_user(self, name):
        users = [user for user in self.user_list if name in user.name]
        return users


    def get_history(self):
        for mark in self.history:
            print(mark)

lib = Library()

book = Book("1984", "Orwell", 1949, "123", 2)
user = User("Alex", "001")

lib.add_book(book)
lib.add_user(user)

lib.issue_book(user, book)
lib.return_book(user, book)

lib.get_history()
# Out:
# {'user': 'Alex', 'book': '1984', 'action': 'issued', 'date': datetime.datetime(2026, 5, 14, 10, 54, 1, 545508)}
# {'user': 'Alex', 'book': '1984', 'action': 'returned', 'date': datetime.datetime(2026, 5, 14, 10, 54, 1, 545543)}

# %% [markdown]
# Explain why list b changes after the execution of the following code:
#
# a = [1, 2, 3]
# b = a
# a[0] = 4
# print(b)

# %% [markdown]
# мы создаем не новый список, а только ссылку на список, на который также ссылается и а, поэтому, написав a[0] = 4, мы поменяли ячейку памяти, а значит и "список" b

# %%
import math

def compute_sums(n):
    A = 0.0
    for i in range(1, n + 1):
        A += 1 / (i * i)


    B = 0.0
    for i in range(n, 0, -1):
        B += 1 / (i * i)

    return A, B

n = 10000
A, B = compute_sums(n)

exact = math.pi**2 / 6 - 1/n

print(f"A (прямой порядок) = {A:.15f}")
print(f"B (обратный порядок) = {B:.15f}")
print(f"Разница A - B = {A - B:.15e}")
print(f"Ошибка A: {abs(A - exact):.15e}")
print(f"Ошибка B: {abs(B - exact):.15e}")
# Out:
# A (прямой порядок) = 1.644834071848065
# B (обратный порядок) = 1.644834071848060
# Разница A - B = 5.551115123125783e-15
# Ошибка A: 4.999838765229470e-09
# Ошибка B: 4.999833214114346e-09

# %% [markdown]
# При вычислении на компьютере A и B немного отличаются из-за ошибок округления при сложении чисел с плавающей точкой. B (суммирование от i 10000 до 1) точнее, потому что сначала складываются малые члены, и они меньше теряются на фоне растущей суммы.
